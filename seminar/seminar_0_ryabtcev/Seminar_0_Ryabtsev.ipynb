# %% [markdown]
# *Emphasis*
# ===========

# %% [markdown]
# *Line 1*   **Line 2**
#
# _Line 3_   __Line 4__

# %% [markdown]
# Header
# ========

# %% [markdown]
# Header 2
# -------------------------

# %% [markdown]
# ### Header 3

# %% [markdown]
# ####Header 4

# %% [markdown]
# *Lists*
# =====

# %% [markdown]
# ###Unordered List

# %% [markdown]
# * Item 1
#
# * Item 2
#
#   * Item 2a
#
#   * Item 2b

# %% [markdown]
# ###Ordered List

# %% [markdown]
# 1. Item 1
# 2. Item 2
# 3. Item 3
#    * Item 3a
#    * Item 3b

# %% [markdown]
# *Manual Line Breaks*
# ====================

# %% [markdown]
# Roses are red,                                                               Violets are blue.

# %% [markdown]
# *Links*
# ====================

# %% [markdown]
# http://example.com
#
# [linked phrase](http://example.com)

# %% [markdown]
# *Images*
# ====================

# %% [markdown]
# ![alt text](http://img-fotki.yandex.ru/get/9300/102699435.9d8/0_b88f4_8fa30144_L.jpg)
#
# [alt text](https://drive.google.com/file/d/1B_Y-dQ4WeO8e7hwBZu7De9c1QE_J-dB6/view?usp=sharing)

# %% [markdown]
# *Blockqutes*
# ====================

# %% [markdown]
# A friend once said:
#
# >It's always better to give
# >than to receive.

# %% [markdown]
# *R Code Blocks*
# ==============

# %% [markdown]
# ```{r}
# summary(cars$dist)
# summary(cars@speed)
# ```

# %% [markdown]
# *Inline R*
# ==============

# %% [markdown]
# There were `r nrow(cars)` cars studied

# %% [markdown]
# *Plain Code Blocks*
# ==============

# %% [markdown]
# ```
# This text is displayed verbatim / preformatted
# ```

# %% [markdown]
# *Inline Code*
# ==============

# %% [markdown]
# We defiend the `add` function to
# compute the sum of two numbers.

# %% [markdown]
# *latex Equations*
# =================

# %% [markdown]
# $equation$

# %% [markdown]
# $latex equation$

# %% [markdown]
# \( equatio\)

# %% [markdown]
# Display Equation
# ----------------

# %% [markdown]
# $$ equation $$

# %% [markdown]
# $$latex equation$$

# %% [markdown]
# \[ equation \]

# %% [markdown]
# *Horizontal Rule/Page break*
# ==========================

# %% [markdown]
# ***********
#
# -----------

# %% [markdown]
# *Tables*
# ========

# %% [markdown]
# First Header | Second Header
# ------------ | -------------
# Content Cell | Content Cell
# Content Cell | Content Cell

# %% [markdown]
# *Reference Style Links and Images*
# =================================

# %% [markdown]
# Links

# %% [markdown]
# A [linked phrase][id].
#
# At the bottom of the document:
#
# [id]: https://www.google.ru/webhp?tab=mw "Title"

# %% [markdown]
# Images

# %% [markdown]
# ![alt text][id]
#
# At the bottom of the document:
#
# [id]: http://img-fotki.yandex.ru/get/9300/102699435.9d8/0_b88f4_8fa30144_L.jpg "Title"

# %% [markdown]
# *Miscellaneous*
# ==============

# %% [markdown]
# superscript^2
#
# ~~strikehrough~~
